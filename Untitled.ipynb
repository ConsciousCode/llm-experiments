# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print("import torch")
import torch
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F

print("import lightning")
import lightning as pl
from lightning.pytorch.callbacks import LearningRateMonitor, Callback
from lightning.pytorch import Trainer, LightningModule

print("import transformers")
from transformers.models.gpt2 import GPT2LMHeadModel, GPT2Tokenizer, GPT2Config

print("import datasets")
from datasets import load_dataset

from collections import OrderedDict

print("import model")
import model
import knn
# Out:
# import torch
# import lightning
# import transformers
# import datasets
# import model

# %%
def map_gpt2_to_infostill(key):
	match key.split('.'):
		case ['wte', x]: return f'embed.{x}'
		case ['h', i, 'ln_1', x]:
			return f"layers.{i}.prenorm.{x}"
		case ['h', i, 'attn', *x]:
			return f"layers.{i}.{'.'.join(x)}"
		case ['ln_f', x]: return f'postnorm.{x}'
		
		# h.?.ln_2, mlp
		case _: return None

class WikiText103DataModule(pl.LightningDataModule):
	def __init__(self, tokenized_dataset, batch_size=8):
		super().__init__()
		self.tokenized_dataset = tokenized_dataset
		self.batch_size = batch_size

	def train_dataloader(self):
		return DataLoader(self.tokenized_dataset['train'], batch_size=self.batch_size, shuffle=True)

	def val_dataloader(self):
		return DataLoader(self.tokenized_dataset['validation'], batch_size=self.batch_size)

class KnowledgeDistillationModule(LightningModule):
	def __init__(self, teacher, student, learning_rate=3e-5, alpha=0.5, temperature=2):
		super().__init__()
		self.teacher = teacher
		self.student = student
		self.learning_rate = learning_rate
		self.alpha = alpha
		self.temperature = temperature
		self.feedback = None

		self.criterion = nn.KLDivLoss(reduction='batchmean')
		self.ce_loss = nn.CrossEntropyLoss()

	def forward(self, input_ids, attention_mask):
		with torch.no_grad():
			teacher_logits = self.teacher(
				input_ids=input_ids,
				attention_mask=attention_mask
			).logits
		
		student_logits, hidden = self.student(
			input_ids=input_ids,
			attention_mask=attention_mask,
			feedback=self.feedback,
			output_hidden_states=True
		)
		print(hidden.shape)
		self.feedback = hidden
		return teacher_logits, student_logits

	def training_step(self, batch, batch_idx):
		input_ids, attention_mask, labels = batch
		teacher_logits, student_logits = self(input_ids, attention_mask)

		loss_kl = self.criterion(
			F.log_softmax(student_logits / self.temperature, dim=-1),
			F.softmax(teacher_logits / self.temperature, dim=-1),
		)
		loss_ce_teacher = self.ce_loss(teacher_logits, labels)
		loss_ce_student = self.ce_loss(student_logits, labels)
		
		# (1 - alpha) * KL + alpha * CE, setting alpha = 0.5
		loss = (loss_kl + loss_ce_student) / 2
		
		self.log('train_loss', {
			"combined": loss,
			"kl": loss_kl,
			"ce_teacher": loss_ce_teacher,
			"ce_student": loss_ce_student
		})

		return loss

	def configure_optimizers(self):
		optimizer = optim.AdamW(self.student.parameters(), lr=self.learning_rate)
		scheduler = optim.lr_scheduler.ReduceLROnPlateau(
			optimizer, max_lr=self.learning_rate,
			steps_per_epoch=100, epochs=self.trainer.max_epochs
		)
		return [optimizer], [scheduler]

class FrequentCheckpoint(Callback):
	def __init__(self, save_steps: int, output_dir: str):
		super().__init__()
		self.save_steps = save_steps
		self.output_dir = output_dir

	def on_batch_end(self, trainer: Trainer, pl_module: LightningModule):
		global_step = trainer.global_step
		if global_step % self.save_steps == 0:
			ckpt_path = os.path.join(self.output_dir, f"checkpoint_step_{global_step}.ckpt")
			trainer.save_checkpoint(ckpt_path)
			print(f"Checkpoint saved at step {global_step}: {ckpt_path}")

# %%
teacher_name = "gpt2-large"

print("Loading teacher")

teacher = GPT2LMHeadModel.from_pretrained(teacher_name)
tokenizer = GPT2Tokenizer.from_pretrained(teacher_name)
config = teacher.config
# Out:
# Loading teacher

# %%
print("Building student")

student = model.InfoDistillery(
    **config.__dict__,
    memory=knn.KNNMemory("orin", config.n_embd)
)
student_state = OrderedDict()

print("Transfer weights")

for teacher_key, teacher_weight in teacher.state_dict().items():
    student_key = map_gpt2_to_infostill(teacher_key)
    if student_key is not None:
        student_state[student_key] = teacher_weight

student.load_state_dict(student_state)
# Out:
# RPC error: [create_collection], <MilvusException: (code=1, message=multiple vector fields is not supported, fields name: key, value)>, <Time:{'RPC start': '2023-04-05 14:18:03.553008', 'RPC error': '2023-04-05 14:18:03.554149'}>
# Building student
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:5                                                                                    │
# │                                                                                                  │
# │    2                                                                                             │
# │    3 student = model.InfoDistillery(                                                             │
# │    4 │   **config.__dict__,                                                                      │
# │ ❱  5 │   memory=knn.KNNMemory("orin", config.n_embd)                                             │
# │    6 )                                                                                           │
# │    7 student_state = OrderedDict()                                                               │
# │    8                                                                                             │
# │                                                                                                  │
# │ /home/consciouscode/Desktop/coding/orin/knn.py:60 in __init__                                    │
# │                                                                                                  │
# │    57 │   │   │   FieldSchema(name="value", dtype=DataType.FLOAT_VECTOR, dim=dim)                │
# │    58 │   │   ], primary_field="id", auto_id=True)                                               │
# │    59 │   │                                                                                      │
# │ ❱  60 │   │   self.collection = Collection(name=self.name, schema=self.schema)                   │
# │    61 │                                                                                          │
# │    62 │   def add(self, keys, values):                                                           │
# │    63 │   │   assert keys.shape[:-1] == values.shape[:-1], "Keys and values should have matchi   │
# │                                                                                                  │
# │ /home/consciouscode/anaconda3/lib/python3.10/site-packages/pymilvus/orm/collection.py:120 in     │
# │ __init__                                                                                         │
# │                                                                                                  │
# │    117 │   │   │   if isinstance(schema, CollectionSchema):                                      │
# │    118 │   │   │   │   check_schema(schema)                                                      │
# │    119 │   │   │   │   consistency_level = get_consistency_level(kwargs.get("consistency_level"  │
# │ ❱  120 │   │   │   │   conn.create_collection(self._name, schema, shards_num=self._shards_num,   │
# │    121 │   │   │   │   self._schema = schema                                                     │
# │    122 │   │   │   │   self._consistency_level = consistency_level                               │
# │    123 │   │   │   else:                                                                         │
# │                                                                                                  │
# │ /home/consciouscode/anaconda3/lib/python3.10/site-packages/pymilvus/decorators.py:109 in handler │
# │                                                                                                  │
# │   106 │   │   │   except MilvusException as e:                                                   │
# │   107 │   │   │   │   record_dict["RPC error"] = str(datetime.datetime.now())                    │
# │   108 │   │   │   │   LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")      │
# │ ❱ 109 │   │   │   │   raise e                                                                    │
# │   110 │   │   │   except grpc.FutureTimeoutError as e:                                           │
# │   111 │   │   │   │   record_dict["gRPC timeout"] = str(datetime.datetime.now())                 │
# │   112 │   │   │   │   LOGGER.error(f"grpc Timeout: [{inner_name}], <{e.__class__.__name__}: {e   │
# │                                                                                                  │
# │ /home/consciouscode/anaconda3/lib/python3.10/site-packages/pymilvus/decorators.py:105 in handler │
# │                                                                                                  │
# │   102 │   │   │   record_dict = {}                                                               │
# │   103 │   │   │   try:                                                                           │
# │   104 │   │   │   │   record_dict["RPC start"] = str(datetime.datetime.now())                    │
# │ ❱ 105 │   │   │   │   return func(*args, **kwargs)                                               │
# │   106 │   │   │   except MilvusException as e:                                                   │
# │   107 │   │   │   │   record_dict["RPC error"] = str(datetime.datetime.now())                    │
# │   108 │   │   │   │   LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")      │
# │                                                                                                  │
# │ /home/consciouscode/anaconda3/lib/python3.10/site-packages/pymilvus/decorators.py:136 in handler │
# │                                                                                                  │
# │   133 │   │   │   │   self.set_onetime_loglevel(level)                                           │
# │   134 │   │   │   if req_id:                                                                     │
# │   135 │   │   │   │   self.set_onetime_request_id(req_id)                                        │
# │ ❱ 136 │   │   │   ret = func(self, *args, **kwargs)                                              │
# │   137 │   │   │   return ret                                                                     │
# │   138 │   │   return handler                                                                     │
# │   139 │   return wrapper                                                                         │
# │                                                                                                  │
# │ /home/consciouscode/anaconda3/lib/python3.10/site-packages/pymilvus/decorators.py:85 in handler  │
# │                                                                                                  │
# │    82 │   │   │   │   │   │   time.sleep(back_off)                                               │
# │    83 │   │   │   │   │   │   back_off = min(back_off * back_off_multiplier, max_back_off)       │
# │    84 │   │   │   │   │   else:                                                                  │
# │ ❱  85 │   │   │   │   │   │   raise e                                                            │
# │    86 │   │   │   │   except Exception as e:                                                     │
# │    87 │   │   │   │   │   raise e                                                                │
# │    88 │   │   │   │   finally:                                                                   │
# │                                                                                                  │
# │ /home/consciouscode/anaconda3/lib/python3.10/site-packages/pymilvus/decorators.py:50 in handler  │
# │                                                                                                  │
# │    47 │   │   │                                                                                  │
# │    48 │   │   │   while True:                                                                    │
# │    49 │   │   │   │   try:                                                                       │
# │ ❱  50 │   │   │   │   │   return func(self, *args, **kwargs)                                     │
# │    51 │   │   │   │   except grpc.RpcError as e:                                                 │
# │    52 │   │   │   │   │   # DEADLINE_EXCEEDED means that the task wat not completed              │
# │    53 │   │   │   │   │   # UNAVAILABLE means that the service is not reachable currently        │
# │                                                                                                  │
# │ /home/consciouscode/anaconda3/lib/python3.10/site-packages/pymilvus/client/grpc_handler.py:212   │
# │ in create_collection                                                                             │
# │                                                                                                  │
# │    209 │   │   │   return rf                                                                     │
# │    210 │   │   status = rf.result()                                                              │
# │    211 │   │   if status.error_code != 0:                                                        │
# │ ❱  212 │   │   │   raise MilvusException(status.error_code, status.reason)                       │
# │    213 │                                                                                         │
# │    214 │   @retry_on_rpc_failure(retry_on_deadline=False)                                        │
# │    215 │   def drop_collection(self, collection_name, timeout=None):                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# MilvusException: <MilvusException: (code=1, message=multiple vector fields is not supported, fields name: key,
# value)>

# %%
pl.seed_everything(42)
block_size = config.n_positions

print("Loading WikiText103")

dataset = load_dataset('wikitext', 'wikitext-103-raw-v1')

print("Tokenizing dataset")

dataset = [
    tokenizer(batch,
        truncation=True, padding='max_length',
        max_length=block_size, return_tensors='pt',
        
    ) for batch in dataset
]
# Out:
# Global seed set to 42
# Loading WikiText103
# Found cached dataset wikitext (/home/consciouscode/.cache/huggingface/datasets/wikitext/wikitext-103-raw-v1/1.0.0/a241db52902eaf2c6aa732210bead40c090019a499ceb13bcbfa3f8ab646a126)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Using pad_token, but it is not set yet.
# Tokenizing dataset
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:10                                                                                   │
# │                                                                                                  │
# │    7                                                                                             │
# │    8 print("Tokenizing dataset")                                                                 │
# │    9                                                                                             │
# │ ❱ 10 dataset = [                                                                                 │
# │   11 │   tokenizer(batch,                                                                        │
# │   12 │   │   truncation=True, padding='max_length',                                              │
# │   13 │   │   max_length=block_size, return_tensors='pt'                                          │
# │                                                                                                  │
# │ in <listcomp>:11                                                                                 │
# │                                                                                                  │
# │    8 print("Tokenizing dataset")                                                                 │
# │    9                                                                                             │
# │   10 dataset = [                                                                                 │
# │ ❱ 11 │   tokenizer(batch,                                                                        │
# │   12 │   │   truncation=True, padding='max_length',                                              │
# │   13 │   │   max_length=block_size, return_tensors='pt'                                          │
# │   14 │   ) for batch in dataset                                                                  │
# │                                                                                                  │
# │ /home/consciouscode/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py: │
# │ 2530 in __call__                                                                                 │
# │                                                                                                  │
# │   2527 │   │   │   # input mode in this case.                                                    │
# │   2528 │   │   │   if not self._in_target_context_manager:                                       │
# │   2529 │   │   │   │   self._switch_to_input_mode()                                              │
# │ ❱ 2530 │   │   │   encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)      │
# │   2531 │   │   if text_target is not None:                                                       │
# │   2532 │   │   │   self._switch_to_target_mode()                                                 │
# │   2533 │   │   │   target_encodings = self._call_one(text=text_target, text_pair=text_pair_targ  │
# │                                                                                                  │
# │ /home/consciouscode/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py: │
# │ 2636 in _call_one                                                                                │
# │                                                                                                  │
# │   2633 │   │   │   │   **kwargs,                                                                 │
# │   2634 │   │   │   )                                                                             │
# │   2635 │   │   else:                                                                             │
# │ ❱ 2636 │   │   │   return self.encode_plus(                                                      │
# │   2637 │   │   │   │   text=text,                                                                │
# │   2638 │   │   │   │   text_pair=text_pair,                                                      │
# │   2639 │   │   │   │   add_special_tokens=add_special_tokens,                                    │
# │                                                                                                  │
# │ /home/consciouscode/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py: │
# │ 2700 in encode_plus                                                                              │
# │                                                                                                  │
# │   2697 │   │   """                                                                               │
# │   2698 │   │                                                                                     │
# │   2699 │   │   # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'           │
# │ ❱ 2700 │   │   padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_tr  │
# │   2701 │   │   │   padding=padding,                                                              │
# │   2702 │   │   │   truncation=truncation,                                                        │
# │   2703 │   │   │   max_length=max_length,                                                        │
# │                                                                                                  │
# │ /home/consciouscode/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py: │
# │ 2435 in _get_padding_truncation_strategies                                                       │
# │                                                                                                  │
# │   2432 │   │                                                                                     │
# │   2433 │   │   # Test if we have a padding token                                                 │
# │   2434 │   │   if padding_strategy != PaddingStrategy.DO_NOT_PAD and (not self.pad_token or sel  │
# │ ❱ 2435 │   │   │   raise ValueError(                                                             │
# │   2436 │   │   │   │   "Asking to pad but the tokenizer does not have a padding token. "         │
# │   2437 │   │   │   │   "Please select a token to use as `pad_token` `(tokenizer.pad_token = tok  │
# │   2438 │   │   │   │   "or add a new pad token via `tokenizer.add_special_tokens({'pad_token':   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Asking to pad but the tokenizer does not have a padding token. Please select a token to use as
# `pad_token` `(tokenizer.pad_token = tokenizer.eos_token e.g.)` or add a new pad token via
# `tokenizer.add_special_tokens({'pad_token': '[PAD]'})`.

# %%
print("Begin training")

trainer = pl.Trainer(gpus=1, max_epochs=3, progress_bar_refresh_rate=20)
trainer.fit(
    KnowledgeDistillationModule(teacher, student),
    datamodule=WikiText103DataModule(dataset),
    callbacks=[
        LearningRateMonitor(logging_interval='step'),
        FrequentCheckpoint(save_steps=1000, output_dir="checkpoints")
    ]
)
# Out:
# Begin training
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │    1 print("Begin training")                                                                     │
# │    2                                                                                             │
# │ ❱  3 trainer = pl.Trainer(gpus=1, max_epochs=3, progress_bar_refresh_rate=20)                    │
# │    4 trainer.fit(                                                                                │
# │    5 │   KnowledgeDistillationModule(teacher, student),                                          │
# │    6 │   datamodule=WikiText103DataModule(dataset),                                              │
# │                                                                                                  │
# │ /home/consciouscode/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/argparse.py: │
# │ 69 in insert_env_defaults                                                                        │
# │                                                                                                  │
# │   66 │   │   kwargs = dict(list(env_variables.items()) + list(kwargs.items()))                   │
# │   67 │   │                                                                                       │
# │   68 │   │   # all args were already moved to kwargs                                             │
# │ ❱ 69 │   │   return fn(self, **kwargs)                                                           │
# │   70 │                                                                                           │
# │   71 │   return cast(_T, insert_env_defaults)                                                    │
# │   72                                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: Trainer.__init__() got an unexpected keyword argument 'gpus'
